# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
house = pd.read_csv(r"C:\Users\mirhan\Downloads\house-data.csv")

# %%
house = house.drop(["date"] , axis= 1)

# %%
house = house.select_dtypes(exclude=["object"])

# %%
h = house.corr()

# %%
sns.heatmap(h,annot=True)
# Out:
# <Axes: >

# %%
plt.scatter(house["sqft_living"],house["bedrooms"])
plt.show()
