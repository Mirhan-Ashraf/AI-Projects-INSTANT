# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
df = pd.read_csv(r"C:\Users\mirhan\Downloads\archive (9)\dailyActivity_merged.csv")

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    4/12/2016       13162       8.500000         8.500000
# 1    1503960366    4/13/2016       10735       6.970000         6.970000
# 2    1503960366    4/14/2016       10460       6.740000         6.740000
# 3    1503960366    4/15/2016        9762       6.280000         6.280000
# 4    1503960366    4/16/2016       12669       8.160000         8.160000
# ..          ...          ...         ...            ...              ...
# 935  8877689391     5/8/2016       10686       8.110000         8.110000
# 936  8877689391     5/9/2016       20226      18.250000        18.250000
# 937  8877689391    5/10/2016       10733       8.150000         8.150000
# 938  8877689391    5/11/2016       21420      19.559999        19.559999
# 939  8877689391    5/12/2016        8064       6.120000         6.120000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
df.Id.nunique()
# Out:
# 33

# %%
colms = ["Id","ActivityDate","TotalSteps","VeryActiveDistance","FairlyActiveMinutes","LightlyActiveMinutes","SedentaryMinutes","Calories" ]
df = df[colms]

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  VeryActiveDistance  \
# 0    1503960366    4/12/2016       13162                1.88
# 1    1503960366    4/13/2016       10735                1.57
# 2    1503960366    4/14/2016       10460                2.44
# 3    1503960366    4/15/2016        9762                2.14
# 4    1503960366    4/16/2016       12669                2.71
# ..          ...          ...         ...                 ...
# 935  8877689391     5/8/2016       10686                1.08
# 936  8877689391     5/9/2016       20226               11.10
# 937  8877689391    5/10/2016       10733                1.35
# 938  8877689391    5/11/2016       21420               13.22
# 939  8877689391    5/12/2016        8064                1.82
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                     13                   328               728      1985
# 1                     19                   217               776      1797
# ...

# %%
df["TotalMin"] = df.VeryActiveDistance + df.FairlyActiveMinutes + df.SedentaryMinutes + df.LightlyActiveMinutes
# Out:
# C:\Users\mirhan\AppData\Local\Temp\ipykernel_28820\746778414.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["TotalMin"] = df.VeryActiveDistance + df.FairlyActiveMinutes + df.SedentaryMinutes + df.LightlyActiveMinutes

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  VeryActiveDistance  \
# 0    1503960366    4/12/2016       13162                1.88
# 1    1503960366    4/13/2016       10735                1.57
# 2    1503960366    4/14/2016       10460                2.44
# 3    1503960366    4/15/2016        9762                2.14
# 4    1503960366    4/16/2016       12669                2.71
# ..          ...          ...         ...                 ...
# 935  8877689391     5/8/2016       10686                1.08
# 936  8877689391     5/9/2016       20226               11.10
# 937  8877689391    5/10/2016       10733                1.35
# 938  8877689391    5/11/2016       21420               13.22
# 939  8877689391    5/12/2016        8064                1.82
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     13                   328               728      1985
# 1                     19                   217               776      1797
# ...

# %%
df["TotalHours"] = round(df.TotalMin/60)
# Out:
# C:\Users\mirhan\AppData\Local\Temp\ipykernel_28820\4108654329.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["TotalHours"] = round(df.TotalMin/60)

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  VeryActiveDistance  \
# 0    1503960366    4/12/2016       13162                1.88
# 1    1503960366    4/13/2016       10735                1.57
# 2    1503960366    4/14/2016       10460                2.44
# 3    1503960366    4/15/2016        9762                2.14
# 4    1503960366    4/16/2016       12669                2.71
# ..          ...          ...         ...                 ...
# 935  8877689391     5/8/2016       10686                1.08
# 936  8877689391     5/9/2016       20226               11.10
# 937  8877689391    5/10/2016       10733                1.35
# 938  8877689391    5/11/2016       21420               13.22
# 939  8877689391    5/12/2016        8064                1.82
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     13                   328               728      1985
# 1                     19                   217               776      1797
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Id                    940 non-null    int64
#  1   ActivityDate          940 non-null    object
#  2   TotalSteps            940 non-null    int64
#  3   VeryActiveDistance    940 non-null    float64
#  4   FairlyActiveMinutes   940 non-null    int64
#  5   LightlyActiveMinutes  940 non-null    int64
#  6   SedentaryMinutes      940 non-null    int64
#  7   Calories              940 non-null    int64
#  8   TotalMin              940 non-null    float64
#  9   TotalHours            940 non-null    float64
# dtypes: float64(3), int64(6), object(1)
# memory usage: 73.6+ KB

# %%
df.ActivityDate= pd.to_datetime(df. ActivityDate)
# Out:
# C:\Users\mirhan\AppData\Local\Temp\ipykernel_28820\2621305982.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ActivityDate= pd.to_datetime(df. ActivityDate)

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  VeryActiveDistance  \
# 0    1503960366   2016-04-12       13162                1.88
# 1    1503960366   2016-04-13       10735                1.57
# 2    1503960366   2016-04-14       10460                2.44
# 3    1503960366   2016-04-15        9762                2.14
# 4    1503960366   2016-04-16       12669                2.71
# ..          ...          ...         ...                 ...
# 935  8877689391   2016-05-08       10686                1.08
# 936  8877689391   2016-05-09       20226               11.10
# 937  8877689391   2016-05-10       10733                1.35
# 938  8877689391   2016-05-11       21420               13.22
# 939  8877689391   2016-05-12        8064                1.82
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     13                   328               728      1985
# 1                     19                   217               776      1797
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Id                    940 non-null    int64
#  1   ActivityDate          940 non-null    datetime64[ns]
#  2   TotalSteps            940 non-null    int64
#  3   VeryActiveDistance    940 non-null    float64
#  4   FairlyActiveMinutes   940 non-null    int64
#  5   LightlyActiveMinutes  940 non-null    int64
#  6   SedentaryMinutes      940 non-null    int64
#  7   Calories              940 non-null    int64
#  8   TotalMin              940 non-null    float64
#  9   TotalHours            940 non-null    float64
# dtypes: datetime64[ns](1), float64(3), int64(6)
# memory usage: 73.6 KB

# %%
import datetime as dt
df["DayOfWeeek"] = df.ActivityDate.dt.day_name()
# Out:
# C:\Users\mirhan\AppData\Local\Temp\ipykernel_28820\1033145905.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DayOfWeeek"] = df.ActivityDate.dt.day_name()

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  VeryActiveDistance  \
# 0    1503960366   2016-04-12       13162                1.88
# 1    1503960366   2016-04-13       10735                1.57
# 2    1503960366   2016-04-14       10460                2.44
# 3    1503960366   2016-04-15        9762                2.14
# 4    1503960366   2016-04-16       12669                2.71
# ..          ...          ...         ...                 ...
# 935  8877689391   2016-05-08       10686                1.08
# 936  8877689391   2016-05-09       20226               11.10
# 937  8877689391   2016-05-10       10733                1.35
# 938  8877689391   2016-05-11       21420               13.22
# 939  8877689391   2016-05-12        8064                1.82
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     13                   328               728      1985
# 1                     19                   217               776      1797
# ...

# %%
df.isnull().sum()
# Out:
# Id                      0
# ActivityDate            0
# TotalSteps              0
# VeryActiveDistance      0
# FairlyActiveMinutes     0
# LightlyActiveMinutes    0
# SedentaryMinutes        0
# Calories                0
# TotalMin                0
# TotalHours              0
# DayOfWeeek              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#                  Id                   ActivityDate    TotalSteps  \
# count  9.400000e+02                            940    940.000000
# mean   4.855407e+09  2016-04-26 06:53:37.021276672   7637.910638
# min    1.503960e+09            2016-04-12 00:00:00      0.000000
# 25%    2.320127e+09            2016-04-19 00:00:00   3789.750000
# 50%    4.445115e+09            2016-04-26 00:00:00   7405.500000
# 75%    6.962181e+09            2016-05-04 00:00:00  10727.000000
# max    8.877689e+09            2016-05-12 00:00:00  36019.000000
# std    2.424805e+09                            NaN   5087.150742
#
#        VeryActiveDistance  FairlyActiveMinutes  LightlyActiveMinutes  \
# count          940.000000           940.000000            940.000000
# mean             1.502681            13.564894            192.812766
# min              0.000000             0.000000              0.000000
# 25%              0.000000             0.000000            127.000000
# ...

# %%
plt.figure(figsize= ((6,4)))
plt.hist(df.DayOfWeeek, bins=7, color= "blue", width = 0.4)
plt.grid(True)

plt.xlabel("Day of Week")
plt.ylabel("Frequency")

plt.title("Frequency by day of week")
plt.show()

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  VeryActiveDistance  \
# 0    1503960366   2016-04-12       13162                1.88
# 1    1503960366   2016-04-13       10735                1.57
# 2    1503960366   2016-04-14       10460                2.44
# 3    1503960366   2016-04-15        9762                2.14
# 4    1503960366   2016-04-16       12669                2.71
# ..          ...          ...         ...                 ...
# 935  8877689391   2016-05-08       10686                1.08
# 936  8877689391   2016-05-09       20226               11.10
# 937  8877689391   2016-05-10       10733                1.35
# 938  8877689391   2016-05-11       21420               13.22
# 939  8877689391   2016-05-12        8064                1.82
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     13                   328               728      1985
# 1                     19                   217               776      1797
# ...

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 df.corr()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10707, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10705 cols = data.columns
#   10706 idx = cols.copy()
# > 10707 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10709 if method == "pearson":
#   10710     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1892, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1890 if dtype is not None:
#    1891     dtype = np.dtype(dtype)
# -> 1892 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1893 if result.dtype is not dtype:
#    1894     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
sns.heatmap(df.corr())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 sns.heatmap(df.corr())
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10707, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10705 cols = data.columns
#   10706 idx = cols.copy()
# > 10707 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10709 if method == "pearson":
#   10710     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1892, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1890 if dtype is not None:
#    1891     dtype = np.dtype(dtype)
# -> 1892 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1893 if result.dtype is not dtype:
#    1894     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
plt.figure(figsize=((8,6)))
plt.scatter(df.TotalSteps , df.Calories , c= df.Calories)

median_steps = 7405
median_calories = 2134

plt.axhline(median_calories , color = "blue" , label = "median of calories")
plt.axvline(median_steps , color = "red" , label = "median of steps")


plt.xlabel("steps")
plt.ylabel("calories")

plt.title("Calories By Total Steps")
plt.legend()
plt.show()

# %%
plt.figure(figsize=((8,6)))
plt.scatter(df.TotalHours , df.Calories , c= df.Calories)

median_hours = 23
median_calories = 2134

plt.axhline(median_calories , color = "blue" , label = "median of calories")
plt.axvline(median_hours , color = "red" , label = "median of hours")


plt.xlabel("hours")
plt.ylabel("calories")

plt.title("Calories By Total Hours")
plt.legend()
plt.show()

# %%
FairlyActiveMinutes = df.FairlyActiveMinutes.sum()
LightlyActiveMinutes = df.LightlyActiveMinutes.sum()
SedentaryMinutes = df.SedentaryMinutes.sum()

minutes = [FairlyActiveMinutes, LightlyActiveMinutes, SedentaryMinutes]
labels =  ["FairlyActiveMinutes", "LightlyActiveMinutes", "SedentaryMinutes"]

plt.pie(minutes, labels=labels, autopct="%1.1f%%", explode = [0, 0, 0.1])
plt.show()
