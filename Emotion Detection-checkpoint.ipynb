# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import pathlib

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
# store directories paths 
train_dir = pathlib.Path(r"C:\Users\mirhan\Downloads\train")
test_dir = pathlib.Path(r"C:\Users\mirhan\Downloads\test")

# count the number of images in each folder (train / test)
train_image_count = len(list(train_dir.glob('*/*.png')))  
test_image_count = len(list(test_dir.glob('*/*.png')))
print(train_image_count)
print(test_image_count)
# Out:
# 28709
# 7178

# %%
# initiate our hyperparameters
batch_size = 32
img_height = 48
img_width = 48

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(train_dir,validation_split=0.2,subset="training",seed=123,
                                                       image_size=(img_height, img_width),batch_size=batch_size)
val_ds = tf.keras.utils.image_dataset_from_directory(train_dir,validation_split=0.2,subset="validation",seed=123,image_size=(img_height, img_width),batch_size=batch_size)
test_ds = tf.keras.utils.image_dataset_from_directory(test_dir, seed=123,image_size=(img_height, img_width),batch_size=batch_size)
# Out:
# Found 28709 files belonging to 7 classes.
# Using 22968 files for training.
# Found 28709 files belonging to 7 classes.
# Using 5741 files for validation.
# Found 7178 files belonging to 7 classes.

# %%
# Extract classes 
class_names = train_ds.class_names
print(class_names)
# Out:
# ['angry', 'disgusted', 'fearful', 'happy', 'neutral', 'sad', 'surprised']

# %%
# Visualize Images

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
# Building CNN model

num_classes = len(class_names)

model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 48, 48, 3)         0
#
#  conv2d (Conv2D)             (None, 48, 48, 16)        448
#
#  max_pooling2d (MaxPooling2  (None, 24, 24, 16)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 32)        4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 12, 12, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 64)        18496
#
#  max_pooling2d_2 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense_4 (Dense)             (None, 128)               295040
#
#  dense_5 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 319527 (1.22 MB)
# Trainable params: 319527 (1.22 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Traning  model

epochs=10
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 718/718 [==============================] - 81s 92ms/step - loss: 1.6550 - accuracy: 0.3408 - val_loss: 1.4897 - val_accuracy: 0.4316
# Epoch 2/10
# 718/718 [==============================] - 72s 100ms/step - loss: 1.3987 - accuracy: 0.4665 - val_loss: 1.3592 - val_accuracy: 0.4767
# Epoch 3/10
# 718/718 [==============================] - 71s 99ms/step - loss: 1.2678 - accuracy: 0.5188 - val_loss: 1.2923 - val_accuracy: 0.5144
# Epoch 4/10
# 718/718 [==============================] - 70s 97ms/step - loss: 1.1704 - accuracy: 0.5594 - val_loss: 1.2794 - val_accuracy: 0.5255
# Epoch 5/10
# 718/718 [==============================] - 69s 97ms/step - loss: 1.0836 - accuracy: 0.5937 - val_loss: 1.2499 - val_accuracy: 0.5403
# Epoch 6/10
# 718/718 [==============================] - 69s 97ms/step - loss: 1.0014 - accuracy: 0.6235 - val_loss: 1.3138 - val_accuracy: 0.5332
# Epoch 7/10
# 718/718 [==============================] - 70s 97ms/step - loss: 0.9113 - accuracy: 0.6573 - val_loss: 1.2861 - val_accuracy: 0.5273
# Epoch 8/10
# 718/718 [==============================] - 68s 95ms/step - loss: 0.8164 - accuracy: 0.6977 - val_loss: 1.3080 - val_accuracy: 0.5551
# Epoch 9/10
# 718/718 [==============================] - 70s 97ms/step - loss: 0.7259 - accuracy: 0.7332 - val_loss: 1.3807 - val_accuracy: 0.5403
# Epoch 10/10
# 718/718 [==============================] - 68s 95ms/step - loss: 0.6288 - accuracy: 0.7734 - val_loss: 1.5087 - val_accuracy: 0.5435

# %%
# Evaluate the model

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %%
# Rebuilding the model with data augmentation layer

model = Sequential([
  data_augmentation,
  layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes, name="outputs")
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_3 (Sequential)   (None, 48, 48, 3)         0
#
#  rescaling_2 (Rescaling)     (None, 48, 48, 3)         0
#
#  conv2d_3 (Conv2D)           (None, 48, 48, 16)        448
#
#  max_pooling2d_3 (MaxPoolin  (None, 24, 24, 16)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 24, 24, 32)        4640
#
#  max_pooling2d_4 (MaxPoolin  (None, 12, 12, 32)        0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 12, 12, 64)        18496
#
#  max_pooling2d_5 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  dropout (Dropout)           (None, 6, 6, 64)          0
#
#  flatten_1 (Flatten)         (None, 2304)              0
#
#  dense_6 (Dense)             (None, 128)               295040
#
#  outputs (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 319527 (1.22 MB)
# Trainable params: 319527 (1.22 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
earlyStoppingCallback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', 
                                                         patience=5,
                                                         verbose= 1 ,
                                                         restore_best_weights=True
                                                        )

epochs = 10
history = model.fit(train_ds,validation_data=val_ds,epochs=epochs, callbacks= [earlyStoppingCallback])
# Out:
# Epoch 1/10
# 718/718 [==============================] - 30s 39ms/step - loss: 1.7718 - accuracy: 0.2661 - val_loss: 1.7056 - val_accuracy: 0.3050
# Epoch 2/10
# 718/718 [==============================] - 26s 36ms/step - loss: 1.6469 - accuracy: 0.3489 - val_loss: 1.5459 - val_accuracy: 0.4111
# Epoch 3/10
# 718/718 [==============================] - 28s 39ms/step - loss: 1.5355 - accuracy: 0.4071 - val_loss: 1.4824 - val_accuracy: 0.4245
# Epoch 4/10
# 718/718 [==============================] - 33s 46ms/step - loss: 1.4602 - accuracy: 0.4358 - val_loss: 1.3939 - val_accuracy: 0.4639
# Epoch 5/10
# 718/718 [==============================] - 32s 45ms/step - loss: 1.4035 - accuracy: 0.4575 - val_loss: 1.3415 - val_accuracy: 0.4914
# Epoch 6/10
# 718/718 [==============================] - 27s 38ms/step - loss: 1.3666 - accuracy: 0.4736 - val_loss: 1.3264 - val_accuracy: 0.4964
# Epoch 7/10
# 718/718 [==============================] - 26s 36ms/step - loss: 1.3396 - accuracy: 0.4863 - val_loss: 1.3006 - val_accuracy: 0.5039
# Epoch 8/10
# 718/718 [==============================] - 26s 37ms/step - loss: 1.3114 - accuracy: 0.4982 - val_loss: 1.3120 - val_accuracy: 0.5010
# Epoch 9/10
# 718/718 [==============================] - 26s 36ms/step - loss: 1.2998 - accuracy: 0.5018 - val_loss: 1.2963 - val_accuracy: 0.5109
# Epoch 10/10
# 718/718 [==============================] - 27s 37ms/step - loss: 1.2865 - accuracy: 0.5058 - val_loss: 1.2934 - val_accuracy: 0.5074

# %%
# Evaluate the model on the test set
loss, accuracy = model.evaluate(test_ds)

# Print the loss and accuracy
print("Loss: ", loss)
print("Accuracy: ", accuracy)
# Out:
# 225/225 [==============================] - 3s 13ms/step - loss: 1.2718 - accuracy: 0.5110
# Loss:  1.2718130350112915
# Accuracy:  0.5110058784484863

# %%
im_path = r"C:\Users\mirhan\Downloads\test\happy\im98.png"
img = tf.keras.utils.load_img(
    im_path, target_size=(img_height, img_width)
)
print(img.size)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch
print(img_array.shape)
predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# (48, 48)
# (1, 48, 48, 3)
# 1/1 [==============================] - 0s 266ms/step
# This image most likely belongs to happy with a 96.06 percent confidence.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
model.save("EmotionDetecttor_2")
# Out:
# INFO:tensorflow:Assets written to: EmotionDetecttor_2\assets
# INFO:tensorflow:Assets written to: EmotionDetecttor_2\assets

# %%
recons_model = tf.keras.models.load_model("EmotionDetecttor_2")

# %%
pr = recons_model.predict(img_array)
sc=tf.nn.softmax(pr[0])
print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(sc)], 100 * np.max(sc))
)
# Out:
# 1/1 [==============================] - 0s 187ms/step
# This image most likely belongs to happy with a 96.06 percent confidence.

# %%
from keras.applications.mobilenet import MobileNet
from keras.layers import Flatten,Activation, Dense

# %%
base_mobilenet_model = MobileNet(weights = None,
                                 include_top = False,
                                 input_shape = (48, 48,3)
                                 )

#Build the Custom mobilenet Model

def mobilenet_custom():
    model = Sequential()
    #add mobilenet conv model
    model.add(base_mobilenet_model)
    #add new layers
    model.add(Flatten())
    model.add(Dense(7,  kernel_initializer='normal'))
    model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])    
    return model

# %%
model = mobilenet_custom()
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenet_1.00_48 (Functio  (None, 1, 1, 1024)        3228864
#  nal)
#
#  flatten_2 (Flatten)         (None, 1024)              0
#
#  dense_7 (Dense)             (None, 7)                 7175
#
# =================================================================
# Total params: 3236039 (12.34 MB)
# Trainable params: 3214151 (12.26 MB)
# Non-trainable params: 21888 (85.50 KB)
# _________________________________________________________________

# %%
history = model.fit(train_ds,validation_data=val_ds,epochs=epochs, callbacks= [earlyStoppingCallback])
# Out:
# Epoch 1/10
# 718/718 [==============================] - 153s 214ms/step - loss: 1.7014 - accuracy: 0.3410 - val_loss: 2.8081 - val_accuracy: 0.1883
# Epoch 2/10
# 718/718 [==============================] - 240s 334ms/step - loss: 1.5848 - accuracy: 0.3910 - val_loss: 1.7403 - val_accuracy: 0.3463
# Epoch 3/10
# 718/718 [==============================] - 326s 454ms/step - loss: 1.5519 - accuracy: 0.4076 - val_loss: 1.6114 - val_accuracy: 0.4085
# Epoch 4/10
# 718/718 [==============================] - 317s 442ms/step - loss: 1.5168 - accuracy: 0.4234 - val_loss: 3.1582 - val_accuracy: 0.2778
# Epoch 5/10
# 718/718 [==============================] - 314s 437ms/step - loss: 1.4604 - accuracy: 0.4419 - val_loss: 1.5000 - val_accuracy: 0.4318
# Epoch 6/10
# 718/718 [==============================] - 313s 436ms/step - loss: 1.3990 - accuracy: 0.4664 - val_loss: 1.6803 - val_accuracy: 0.3837
# Epoch 7/10
# 718/718 [==============================] - 319s 444ms/step - loss: 1.3631 - accuracy: 0.4818 - val_loss: 1.4811 - val_accuracy: 0.4173
# Epoch 8/10
# 718/718 [==============================] - 320s 446ms/step - loss: 1.2826 - accuracy: 0.5162 - val_loss: 1.5491 - val_accuracy: 0.4252
# Epoch 9/10
# 718/718 [==============================] - 240s 334ms/step - loss: 1.2332 - accuracy: 0.5340 - val_loss: 1.5006 - val_accuracy: 0.4280
# Epoch 10/10
# 718/718 [==============================] - 139s 193ms/step - loss: 1.1867 - accuracy: 0.5554 - val_loss: 1.4912 - val_accuracy: 0.4517

# %%
im_path = r"C:\Users\mirhan\Downloads\test\happy\im98.png"
img = tf.keras.utils.load_img(
    im_path, target_size=(img_height, img_width)
)
print(img.size)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch
print(img_array.shape)
predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# (48, 48)
# (1, 48, 48, 3)
# 1/1 [==============================] - 1s 700ms/step
# This image most likely belongs to happy with a 90.05 percent confidence.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
